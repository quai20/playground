# %%
import xarray as xr
from pydap.cas.urs import setup_session
url = 'https://goldsmr4.gesdisc.eosdis.nasa.gov/dods/M2T1NXADG'
session = setup_session(username='kbalem', password='*******', check_url=url)
store = xr.backends.PydapDataStore.open(url, session=session)
ds = xr.open_dataset(store)
ds
# Out:
# /export/home/anaconda3/envs/nemoparcels/lib/python3.9/site-packages/xarray/coding/times.py:150: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:0.0. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:0.0). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)
# <xarray.Dataset>
# Dimensions:   (time: 373272, lat: 361, lon: 576)
# Coordinates:
#   * time      (time) datetime64[ns] 1980-01-01T00:30:00.000003 ... 2022-07-31...
#   * lat       (lat) float64 -90.0 -89.5 -89.0 -88.5 ... 88.5 89.0 89.5 90.0
#   * lon       (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
# Data variables: (12/115)
#     bcdp001   (time, lat, lon) float32 ...
#     bcdp002   (time, lat, lon) float32 ...
#     bcem001   (time, lat, lon) float32 ...
#     bcem002   (time, lat, lon) float32 ...
#     bceman    (time, lat, lon) float32 ...
#     bcembb    (time, lat, lon) float32 ...
#     ...        ...
#     susv003   (time, lat, lon) float32 ...
#     susv004   (time, lat, lon) float32 ...
#     suwt001   (time, lat, lon) float32 ...
#     suwt002   (time, lat, lon) float32 ...
#     suwt003   (time, lat, lon) float32 ...
#     suwt004   (time, lat, lon) float32 ...
# Attributes:
#     title:        MERRA-2 tavg1_2d_adg_Nx: 2d,1-Hourly,Time-averaged,Single-L...
#     Conventions:  ['COARDS', 'GrADS']
#     dataType:     Grid
#     history:      Sun Sep 04 13:36:01 GMT 2022 : imported by GrADS Data Serve...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,8))
ds['duwt001'].isel(time=200000).plot(vmin=-1e-16,vmax=5e-13)
